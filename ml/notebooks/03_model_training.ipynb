# %% [markdown]
# # 03 - Model Training
# Training XGBoost, Prophet, and ensemble models.

# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from prophet import Prophet
from sklearn.metrics import mean_absolute_percentage_error
import shap
