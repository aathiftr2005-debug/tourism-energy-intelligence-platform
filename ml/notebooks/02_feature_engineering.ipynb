# %% [markdown]
# # 02 - Feature Engineering
# Creating lag, rolling, and seasonal features.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '../../backend')
from app.ml.features import build_feature_pipeline
