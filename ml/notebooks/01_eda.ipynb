# %% [markdown]
# # 01 - Exploratory Data Analysis
# Tourism Energy Intelligence
# Analyzing European tourism and energy consumption patterns.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='darkgrid')

# %%
# Load raw data
# !ls ../data/raw/
